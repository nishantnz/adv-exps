# %%
# Load necessary libraries
install.packages(c("ggplot2", "dplyr", "wordcloud", "RColorBrewer", "plotly", "car"))
library(ggplot2)
library(dplyr)
library(wordcloud)
library(RColorBrewer)
library(plotly)
library(car)
# Out:
# Installing packages into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘doBy’, ‘pbkrtest’, ‘lme4’
#
#
#
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
# Loading required package: RColorBrewer
#
#
# Attaching package: ‘plotly’
#
#
# The following object is masked from ‘package:ggplot2’:
#
#     last_plot
#
#
# The following object is masked from ‘package:stats’:
#
#     filter
#
#
# The following object is masked from ‘package:graphics’:
#
#     layout
#
#
# Loading required package: carData
#
#
# Attaching package: ‘car’
#
#
# The following object is masked from ‘package:dplyr’:
#
#     recode

# %%
data <- read.csv("Housing.csv")

# %%
# Word Cloud
# Create a corpus of text data (furnishing status) for the word cloud
furnishing_status <- as.character(data$furnishingstatus)
wordcloud(furnishing_status, scale=c(3,0.5), colors=brewer.pal(8, "Dark2"), random.order=FALSE)
# Out:
# Loading required namespace: tm
#
# Loading required namespace: slam
# Error in loadNamespace(x): there is no package called ‘tm’
# Traceback:
#
# 1. wordcloud(furnishing_status, scale = c(3, 0.5), colors = brewer.pal(8,
#  .     "Dark2"), random.order = FALSE)
# 2. loadNamespace(x)
# 3. withRestarts(stop(cond), retry_loadNamespace = function() NULL)
# 4. withOneRestart(expr, restarts[[1L]])
# 5. doWithOneRestart(return(expr), restart)

# %%
# Box Plot
# Box plot of price by furnishing status
ggplot(data, aes(x=furnishingstatus, y=price, fill=furnishingstatus)) +
  geom_boxplot() +
  labs(title="Box Plot of Price by Furnishing Status", x="Furnishing Status", y="Price") +
  theme_minimal()
# Out:
# plot without title

# %%
# Violin Plot
# Violin plot of price by furnishing status
ggplot(data, aes(x=furnishingstatus, y=price, fill=furnishingstatus)) +
  geom_violin() +
  labs(title="Violin Plot of Price by Furnishing Status", x="Furnishing Status", y="Price") +
  theme_minimal()
# Out:
# plot without title

# %%
# Linear Regression Plot
# Linear regression of price vs. area
ggplot(data, aes(x=area, y=price)) +
  geom_point(aes(color="Data Points")) +
  geom_smooth(method="lm", se=FALSE, color="blue") +
  labs(title="Linear Regression of Price vs. Area", x="Area", y="Price") +
  theme_minimal()
# Out:
# `geom_smooth()` using formula = 'y ~ x'

# %%
# Non-Linear Regression Plot
# Fit a quadratic model for price vs. area
ggplot(data, aes(x=area, y=price)) +
  geom_point(aes(color="Data Points")) +
  geom_smooth(method="lm", formula=y ~ poly(x, 2), se=FALSE, color="red") +
  labs(title="Non-Linear Regression (Quadratic) of Price vs. Area", x="Area", y="Price") +
  theme_minimal()

# %%
# 3D Scatter Plot
# 3D scatter plot of price, area, and bedrooms
plot_ly(data, x = ~area, y = ~price, z = ~bedrooms, color = ~price, colors = colorRamp(c('blue', 'red')), type="scatter3d", mode="markers") %>%
  layout(title="3D Scatter Plot of Price, Area, and Bedrooms", scene = list(xaxis = list(title = 'Area'),
                                                                        yaxis = list(title = 'Price'),
                                                                        zaxis = list(title = 'Bedrooms')))

# %%
# Jitter Plot
# Jitter plot of price by furnishing status
ggplot(data, aes(x=furnishingstatus, y=price, color=furnishingstatus)) +
  geom_jitter(width=0.2, height=0) +
  labs(title="Jitter Plot of Price by Furnishing Status", x="Furnishing Status", y="Price") +
  theme_minimal()
